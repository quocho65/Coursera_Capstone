# %% [markdown]
# # Problem:
# California is a big state of America. The population of California is about 39.56 million (2018).
# California is divided into 58 counties. The investor for a given venue (for example restaurant, hotel) want to know in which counties he/ she should invest.
# One feasible solution is clustering of counties base on some their characteristics such as population, median of income, median of rent
# Also, Number of given venues have already existed in the county. The information of clusters could help the investor to make decision.
# Therefore, in this capstone project, we will collect data of county characteristics. Then, we will cluster the counties of California

# %% [markdown]
# # Data
# At the beginning, we collect data about population, Income, house price and using Foursquare to get information about venues
# of each county. The data sources as below
# 1.	Population : https://www.california-demographics.com/counties_by_population
# 2.	Income : https://en.wikipedia.org/wiki/List_of_California_locations_by_income
# 3.	House Price : https://www.zillow.com/research/data/
# 4.	Foursquare API

# %% [markdown]
# # Load Population and Income data from Wikipedia to Dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
# %matplotlib inline

# %%
url = 'https://en.wikipedia.org/wiki/List_of_California_locations_by_income'
dfs = pd.read_html(url)
dfs[1].head()
# Out:
#       County  Population[1]  Populationdensity[1][2][note 1]  \
# 0    Alameda        1559308                           2109.8
# 1     Alpine           1202                              1.6
# 2     Amador          37159                             62.5
# 3      Butte         221578                            135.4
# 4  Calaveras          44921                             44.0
#
#   Per capita income[3] Median household income[6] Median family income[5]
# 0              $36,439                    $73,775                 $90,822
# 1              $24,375                    $61,343                 $71,932
# 2              $27,373                    $52,964                 $68,765
# 3              $24,430                    $43,165                 $56,934
# 4              $29,296                    $54,936                 $67,100

# %%
df_income = dfs[1]

# %%
df_income.head()
# Out:
#       County  Population[1]  Populationdensity[1][2][note 1]  \
# 0    Alameda        1559308                           2109.8
# 1     Alpine           1202                              1.6
# 2     Amador          37159                             62.5
# 3      Butte         221578                            135.4
# 4  Calaveras          44921                             44.0
#
#   Per capita income[3] Median household income[6] Median family income[5]
# 0              $36,439                    $73,775                 $90,822
# 1              $24,375                    $61,343                 $71,932
# 2              $27,373                    $52,964                 $68,765
# 3              $24,430                    $43,165                 $56,934
# 4              $29,296                    $54,936                 $67,100

# %% [markdown]
# # Column rename

# %%
df_income.columns =['County','Population','Density','Per_capita_income','Household income','Family income']

# %%
df_income.head()
# Out:
#       County  Population  Density Per_capita_income Household income  \
# 0    Alameda     1559308   2109.8           $36,439          $73,775
# 1     Alpine        1202      1.6           $24,375          $61,343
# 2     Amador       37159     62.5           $27,373          $52,964
# 3      Butte      221578    135.4           $24,430          $43,165
# 4  Calaveras       44921     44.0           $29,296          $54,936
#
#   Family income
# 0       $90,822
# 1       $71,932
# 2       $68,765
# 3       $56,934
# 4       $67,100

# %%
df_income.shape
# Out:
# (58, 6)

# %% [markdown]
# # Convert column data type

# %%
df_income['Population'] = df_income['Population'].astype(int)

# %%
df_income[['Per_capita_income']] = df_income[['Per_capita_income']].replace('[\$,]','',regex=True).astype(float)

# %%
df_income[['Household income']] = df_income[['Household income']].replace('[\$,]','',regex=True).astype(float)

# %%
df_income[['Family income']] = df_income[['Family income']].replace('[\$,]','',regex=True).astype(float)

# %%
df_income.head()
# Out:
#       County  Population  Density  Per_capita_income  Household income  \
# 0    Alameda     1559308   2109.8            36439.0           73775.0
# 1     Alpine        1202      1.6            24375.0           61343.0
# 2     Amador       37159     62.5            27373.0           52964.0
# 3      Butte      221578    135.4            24430.0           43165.0
# 4  Calaveras       44921     44.0            29296.0           54936.0
#
#    Family income
# 0        90822.0
# 1        71932.0
# 2        68765.0
# 3        56934.0
# 4        67100.0

# %%
df_income.to_csv('Population_Income.csv')

# %% [markdown]
# # Load House Price from CVS File (Zillow)

# %%
df_house_price = pd.read_csv("County_Zhvi_AllHomes.csv")

# %%
df_house_price.head()
# Out:
#    RegionID          RegionName State                             Metro  \
# 0      3101  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim
# 1       139         Cook County    IL          Chicago-Naperville-Elgin
# 2      1090       Harris County    TX  Houston-The Woodlands-Sugar Land
# 3      2402     Maricopa County    AZ           Phoenix-Mesa-Scottsdale
# 4      2841    San Diego County    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank   1996-04   1996-05   1996-06  \
# 0              6                 37         1  176818.0  176955.0  177134.0
# 1             17                 31         2  148775.0  148353.0  148412.0
# 2             48                201         3  101060.0  101208.0  101305.0
# 3              4                 13         4  118611.0  119312.0  119944.0
# 4              6                 73         5  180776.0  180589.0  180435.0
#
#    ...  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# 0  ...   625786   627162   627902   629576   632000   635385   638392
# 1  ...   246290   246354   246654   246680   246455   246124   245771
# 2  ...   197520   197991   198633   199173   199499   200020   200439
# 3  ...   282783   283993   285447   287281   288866   290643   292529
# 4  ...   593523   595218   596989   598589   600515   602130   605256
#
#    2019-12  2020-01  2020-02
# 0   643078   648206   656790
# 1   245439   245238   245151
# 2   200878   200888   201171
# 3   294716   296854   298760
# 4   609134   614512   619887
#
# [5 rows x 294 columns]

# %%
df_house_price = df_house_price[df_house_price['State']=='CA']

# %%
df_house_price.shape
# Out:
# (58, 294)

# %%
df_house_price = df_house_price[['RegionName','2020-02']]

# %%
df_house_price.columns =['County','HousePrice']

# %%
df_house_price.head()
# Out:
#                    County  HousePrice
# 0      Los Angeles County      656790
# 4        San Diego County      619887
# 5           Orange County      753361
# 10       Riverside County      400012
# 11  San Bernardino County      365759

# %%
df_house_price['County']=df_house_price['County'].replace(' County',"",regex=True)

# %%
df_house_price.head()
# Out:
#             County  HousePrice
# 0      Los Angeles      656790
# 4        San Diego      619887
# 5           Orange      753361
# 10       Riverside      400012
# 11  San Bernardino      365759

# %%
df_house_price.shape
# Out:
# (58, 2)

# %% [markdown]
# # Merge two dataframe

# %%
df = pd.merge(df_income,df_house_price,on='County')

# %%
df.head()
# Out:
#       County  Population  Density  Per_capita_income  Household income  \
# 0    Alameda     1559308   2109.8            36439.0           73775.0
# 1     Alpine        1202      1.6            24375.0           61343.0
# 2     Amador       37159     62.5            27373.0           52964.0
# 3      Butte      221578    135.4            24430.0           43165.0
# 4  Calaveras       44921     44.0            29296.0           54936.0
#
#    Family income  HousePrice
# 0        90822.0      880231
# 1        71932.0      424684
# 2        68765.0      312764
# 3        56934.0      327236
# 4        67100.0      330958

# %%
df.shape
# Out:
# (58, 7)

# %% [markdown]
# # Analyze features

# %%
df.describe()
# Out:
#          Population       Density  Per_capita_income  Household income  \
# count  5.800000e+01     58.000000          58.000000         58.000000
# mean   6.563262e+05    680.206897       27604.344828      56034.362069
# std    1.443529e+06   2381.703846        8198.398555      14428.471908
# min    1.202000e+03      1.600000       16409.000000      35997.000000
# 25%    4.727750e+04     25.725000       21754.250000      44717.250000
# 50%    1.799925e+05    105.900000       26190.000000      53302.000000
# 75%    6.564860e+05    341.000000       30913.750000      63946.750000
# max    9.974203e+06  17680.100000       58004.000000      93854.000000
#
#        Family income    HousePrice
# count      58.000000  5.800000e+01
# mean    66744.344828  4.699471e+05
# std     17164.865156  2.918424e+05
# min     45296.000000  1.307210e+05
# 25%     52788.750000  2.798242e+05
# 50%     62945.000000  3.669245e+05
# 75%     75677.250000  6.177612e+05
# max    120030.000000  1.436140e+06

# %%
corr = df.corr()
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col0 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col2 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col4 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col5 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col1 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col3 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col4 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col5 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row3_col0 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row3_col1 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row3_col2 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row3_col4 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row3_col5 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row4_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row4_col1 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row4_col2 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row4_col3 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row4_col5 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row5_col0 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row5_col1 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row5_col2 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row5_col3 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row5_col4 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Population</th>        <th class="col_heading level0 col1" >Density</th>        <th class="col_heading level0 col2" >Per_capita_income</th>        <th class="col_heading level0 col3" >Household income</th>        <th class="col_heading level0 col4" >Family income</th>        <th class="col_heading level0 col5" >HousePrice</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9level0_row0" class="row_heading level0 row0" >Population</th>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col1" class="data row0 col1" >0.214050</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col2" class="data row0 col2" >0.129885</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col3" class="data row0 col3" >0.213370</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col4" class="data row0 col4" >0.136799</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row0_col5" class="data row0 col5" >0.259032</td>
#             </tr>
#             <tr>
#                         <th id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9level0_row1" class="row_heading level0 row1" >Density</th>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col0" class="data row1 col0" >0.214050</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col2" class="data row1 col2" >0.473253</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col3" class="data row1 col3" >0.355580</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col4" class="data row1 col4" >0.338975</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row1_col5" class="data row1 col5" >0.576835</td>
#             </tr>
#             <tr>
#                         <th id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9level0_row2" class="row_heading level0 row2" >Per_capita_income</th>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col0" class="data row2 col0" >0.129885</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col1" class="data row2 col1" >0.473253</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col3" class="data row2 col3" >0.871630</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col4" class="data row2 col4" >0.935717</td>
#                         <td id="T_8503543e_79ee_11ea_b2bc_d0c6374e52a9row2_col5" class="data row2 col5" >0.891513</td>
#             </tr>
#             <tr>

# %%
sn.set(font_scale=1.5,style="white")
sn.lmplot(x="Per_capita_income",y="HousePrice",data=df)
plt.show()

# %% [markdown]
# # Get Venue Info. from Foursquare

# %%
import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %%
df.head()
# Out:
#       County  Population  Density  Per_capita_income  Household income  \
# 0    Alameda     1559308   2109.8            36439.0           73775.0
# 1     Alpine        1202      1.6            24375.0           61343.0
# 2     Amador       37159     62.5            27373.0           52964.0
# 3      Butte      221578    135.4            24430.0           43165.0
# 4  Calaveras       44921     44.0            29296.0           54936.0
#
#    Family income  HousePrice longitute
# 0        90822.0      880231      None
# 1        71932.0      424684      None
# 2        68765.0      312764      None
# 3        56934.0      327236      None
# 4        67100.0      330958      None

# %%
Counties = pd.Series(df['County'])

# %%
# define the dataframe columns
column_names = ['County', 'Latitude', 'Longitude'] 

# instantiate the dataframe
df_geo = pd.DataFrame(columns=column_names)

# %%
for data in Counties:
    location = geolocator.geocode(data)
    latitude = location.latitude
    longitude = location.longitude
    df_geo = df_geo.append({ 'County': data,
                            'Latitude': latitude,
                            'Longitude': longitude}, ignore_index=True)

# %%
df_geo.head()
# Out:
#       County   Latitude   Longitude
# 0    Alameda  37.609029 -121.899142
# 1     Alpine  38.589393 -119.834501
# 2     Amador  38.449089 -120.591102
# 3      Butte  39.651927 -121.585844
# 4  Calaveras  38.255818 -120.498149

# %%
df_geo.shape
# Out:
# (58, 3)

# 1         71932.0      424684      None  38.589393 -119.834501
# 2         68765.0      312764      None  38.449089 -120.591102
# 3         56934.0      327236      None  39.651927 -121.585844
# 4         67100.0      330958      None  38.255818 -120.498149
# 5         56472.0      241486      None  39.146558 -122.220956
# 6         95087.0      708779      None  37.903481 -121.917535
# 7         52452.0      251191      None  41.726177 -123.913280
# 8         84690.0      486195      None  33.207630  -92.666267
# 9         50046.0      265174      None  36.729529 -119.708861
# 10        51940.0      240063      None  39.591277 -122.377866
# 11        53532.0      324636      None  40.599742 -123.899773
# 12        46555.0      246192      None  33.030549 -115.359567
# 13        69041.0      368090      None  36.559533 -117.407471
# 14        52541.0      232849      None  35.314570 -118.753822
# 15        50202.0      233032      None  36.078481 -119.795634
# 16        47773.0      252768      None  39.050541 -122.777656
# 17        66717.0      170047      None  40.768558 -120.730998
# 18        62289.0      656790      None  34.053691 -118.242767
# 19        49964.0      279723      None  36.941812 -120.171438
# 20       120030.0     1187086      None  38.040914 -122.619964
# 21        63520.0      299882      None  37.570148 -119.903659
# 22        53996.0      398245      None  39.317649 -123.412640
# 23        47729.0      280128      None  37.164154 -120.767860
# 24        46536.0      130721      None  41.545049 -120.743600
# 25        73494.0      474496      None  37.953393 -118.939876
# 26        62370.0      604141      None  36.223108 -121.387743
# 27        81275.0      699077      None  38.297137 -122.285529
# 28        69649.0      476825      None  39.515882 -116.853723
# 29        85472.0      753361      None  33.750038 -117.870493
# 30        88615.0      525269      None  39.101206 -120.765061
# 31        60709.0      283298      None  39.943099 -120.805952
# 32        63523.0      400012      None  33.953355 -117.396162
# 33        64496.0      395943      None  38.581572 -121.494400
# 34        71124.0      643036      None  36.624809 -121.117738
# 35        59626.0      365759      None  34.825302 -116.083314
# 36        74569.0      619887      None  32.717421 -117.162771
# 37        93391.0     1436140      None  37.779026 -122.419906
# 38        59614.0      388920      None  37.937290 -121.277372
# 39        75828.0      639504      None  35.354021 -120.375716
# 40       108088.0     1375001      None  37.496904 -122.333057
# 41        73636.0      652059      None  34.422132 -119.702667
# 42       106401.0     1227246      None  37.233325 -121.684635
# 43        81495.0      855995      None  50.750489   20.782912
# 44        55028.0      280337      None  40.796512 -121.997919
# 45        57708.0      237885      None  39.584907 -120.530573
# 46        46079.0      219256      None  41.500722 -122.544354
# 47        77634.0      452504      None  38.221894 -121.916355
# 48        76614.0      655326      None  38.511080 -122.847339
# 49        55357.0      331033      None  37.550087 -121.050143
# 50        58434.0      318841      None  38.950967 -121.697088
# 51        49731.0      240791      None  40.125133 -122.201553
# 52        49221.0      282881      None  31.083445  -95.121935
# 53        45296.0      226122      None  36.251647 -118.852583
# 54        58355.0      290611      None  38.056944 -119.991935
# 55        86890.0      611384      None  34.445825 -119.077936
# 56        75225.0      472934      None  38.718454 -121.905900
# 57        49560.0      292105      None  39.283975 -121.355682

# %%
address = 'California, CA'

geolocator = Nominatim(user_agent="ca_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of California are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of California are 45.2234573, -76.4969015.

# %%
# create map of New York using latitude and longitude values
map_ca = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng in zip(df['Latitude'], df['Longitude'],df['County']):
    label = '{}'.format(County)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ca)  
    
map_ca
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-8c9de44b9378> in <module>
#       3
#       4 # add markers to map
# ----> 5 for lat, lng in zip(df['Latitude'], df['Longitude'],df['County']):
#       6     label = '{}'.format(County)
#       7     label = folium.Popup(label, parse_html=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
