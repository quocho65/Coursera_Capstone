# %% [markdown]
# # Problem:
# California is a big state of America. The population of California is about 39.56 million (2018).
# California is divided into 58 counties. The investor for a given venue (for example restaurant, hotel) want to know in which counties he/ she should invest.
# One feasible solution is clustering of counties base on some their characteristics such as population, median of income, median of rent
# Also, Number of given venues have already existed in the county. The information of clusters could help the investor to make decision.
# Therefore, in this capstone project, we will collect data of county characteristics. Then, we will cluster the counties of California

# %% [markdown]
# # Data
# At the beginning, we collect data about population, Income, house price and using Foursquare to get information about venues
# of each county. The data sources as below
# 1.	Population : https://www.california-demographics.com/counties_by_population
# 2.	Income : https://en.wikipedia.org/wiki/List_of_California_locations_by_income
# 3.	House Price : https://www.zillow.com/research/data/
# 4.	Foursquare API

# %% [markdown]
# # I. Data preparation

# %% [markdown]
# ## Data Loading from Wiki

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
# %matplotlib inline

# %%
url = 'https://en.wikipedia.org/wiki/List_of_California_locations_by_income'
dfs = pd.read_html(url)
dfs[1].head()
# Out:
#       County  Population[1]  Populationdensity[1][2][note 1]  \
# 0    Alameda        1559308                           2109.8
# 1     Alpine           1202                              1.6
# 2     Amador          37159                             62.5
# 3      Butte         221578                            135.4
# 4  Calaveras          44921                             44.0
#
#   Per capita income[3] Median household income[6] Median family income[5]
# 0              $36,439                    $73,775                 $90,822
# 1              $24,375                    $61,343                 $71,932
# 2              $27,373                    $52,964                 $68,765
# 3              $24,430                    $43,165                 $56,934
# 4              $29,296                    $54,936                 $67,100

# %%
df_income = dfs[1]

# %%
df_income.head()
# Out:
#       County  Population[1]  Populationdensity[1][2][note 1]  \
# 0    Alameda        1559308                           2109.8
# 1     Alpine           1202                              1.6
# 2     Amador          37159                             62.5
# 3      Butte         221578                            135.4
# 4  Calaveras          44921                             44.0
#
#   Per capita income[3] Median household income[6] Median family income[5]
# 0              $36,439                    $73,775                 $90,822
# 1              $24,375                    $61,343                 $71,932
# 2              $27,373                    $52,964                 $68,765
# 3              $24,430                    $43,165                 $56,934
# 4              $29,296                    $54,936                 $67,100

# %% [markdown]
# ## Column renaming

# %%
df_income.columns =['County','Population','Density','Per_capita_income','Household income','Family income']

# %%
df_income.head()
# Out:
#       County  Population  Density Per_capita_income Household income  \
# 0    Alameda     1559308   2109.8           $36,439          $73,775
# 1     Alpine        1202      1.6           $24,375          $61,343
# 2     Amador       37159     62.5           $27,373          $52,964
# 3      Butte      221578    135.4           $24,430          $43,165
# 4  Calaveras       44921     44.0           $29,296          $54,936
#
#   Family income
# 0       $90,822
# 1       $71,932
# 2       $68,765
# 3       $56,934
# 4       $67,100

# %%
df_income.shape
# Out:
# (58, 6)

# %% [markdown]
# ## Column data type converting

# %%
df_income['Population'] = df_income['Population'].astype(int)

# %%
df_income[['Per_capita_income']] = df_income[['Per_capita_income']].replace('[\$,]','',regex=True).astype(float)

# %%
df_income[['Household income']] = df_income[['Household income']].replace('[\$,]','',regex=True).astype(float)

# %%
df_income[['Family income']] = df_income[['Family income']].replace('[\$,]','',regex=True).astype(float)

# %%
df_income.head()
# Out:
#       County  Population  Density  Per_capita_income  Household income  \
# 0    Alameda     1559308   2109.8            36439.0           73775.0
# 1     Alpine        1202      1.6            24375.0           61343.0
# 2     Amador       37159     62.5            27373.0           52964.0
# 3      Butte      221578    135.4            24430.0           43165.0
# 4  Calaveras       44921     44.0            29296.0           54936.0
#
#    Family income
# 0        90822.0
# 1        71932.0
# 2        68765.0
# 3        56934.0
# 4        67100.0

# %%
df_income.to_csv('Population_Income.csv')

# %% [markdown]
# ## Loading House price from Zillow's csv file

# %%
df_house_price = pd.read_csv("County_Zhvi_AllHomes.csv")

# %%
df_house_price.head()
# Out:
#    RegionID          RegionName State                             Metro  \
# 0      3101  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim
# 1       139         Cook County    IL          Chicago-Naperville-Elgin
# 2      1090       Harris County    TX  Houston-The Woodlands-Sugar Land
# 3      2402     Maricopa County    AZ           Phoenix-Mesa-Scottsdale
# 4      2841    San Diego County    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank   1996-04   1996-05   1996-06  \
# 0              6                 37         1  176818.0  176955.0  177134.0
# 1             17                 31         2  148775.0  148353.0  148412.0
# 2             48                201         3  101060.0  101208.0  101305.0
# 3              4                 13         4  118611.0  119312.0  119944.0
# 4              6                 73         5  180776.0  180589.0  180435.0
#
#    ...  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# 0  ...   625786   627162   627902   629576   632000   635385   638392
# 1  ...   246290   246354   246654   246680   246455   246124   245771
# 2  ...   197520   197991   198633   199173   199499   200020   200439
# 3  ...   282783   283993   285447   287281   288866   290643   292529
# 4  ...   593523   595218   596989   598589   600515   602130   605256
#
#    2019-12  2020-01  2020-02
# 0   643078   648206   656790
# 1   245439   245238   245151
# 2   200878   200888   201171
# 3   294716   296854   298760
# 4   609134   614512   619887
#
# [5 rows x 294 columns]

# %%
df_house_price = df_house_price[df_house_price['State']=='CA']

# %%
df_house_price.shape
# Out:
# (58, 294)

# %%
df_house_price = df_house_price[['RegionName','2020-02']]

# %%
df_house_price.columns =['County','HousePrice']

# %%
df_house_price.head()
# Out:
#                    County  HousePrice
# 0      Los Angeles County      656790
# 4        San Diego County      619887
# 5           Orange County      753361
# 10       Riverside County      400012
# 11  San Bernardino County      365759

# %%
df_house_price['County']=df_house_price['County'].replace(' County',"",regex=True)

# %%
df_house_price.head()
# Out:
#             County  HousePrice
# 0      Los Angeles      656790
# 4        San Diego      619887
# 5           Orange      753361
# 10       Riverside      400012
# 11  San Bernardino      365759

# %%
df_house_price.shape
# Out:
# (58, 2)

# %% [markdown]
# ## Merging two dataframes

# %%
df = pd.merge(df_income,df_house_price,on='County')

# %%
df.head()
# Out:
#       County  Population  Density  Per_capita_income  Household income  \
# 0    Alameda     1559308   2109.8            36439.0           73775.0
# 1     Alpine        1202      1.6            24375.0           61343.0
# 2     Amador       37159     62.5            27373.0           52964.0
# 3      Butte      221578    135.4            24430.0           43165.0
# 4  Calaveras       44921     44.0            29296.0           54936.0
#
#    Family income  HousePrice
# 0        90822.0      880231
# 1        71932.0      424684
# 2        68765.0      312764
# 3        56934.0      327236
# 4        67100.0      330958

# %%
df.shape
# Out:
# (58, 7)

# %% [markdown]
# ## Features Analyzing

# %%
df.describe()
# Out:
#          Population       Density  Per_capita_income  Household income  \
# count  5.800000e+01     58.000000          58.000000         58.000000
# mean   6.563262e+05    680.206897       27604.344828      56034.362069
# std    1.443529e+06   2381.703846        8198.398555      14428.471908
# min    1.202000e+03      1.600000       16409.000000      35997.000000
# 25%    4.727750e+04     25.725000       21754.250000      44717.250000
# 50%    1.799925e+05    105.900000       26190.000000      53302.000000
# 75%    6.564860e+05    341.000000       30913.750000      63946.750000
# max    9.974203e+06  17680.100000       58004.000000      93854.000000
#
#        Family income    HousePrice
# count      58.000000  5.800000e+01
# mean    66744.344828  4.699471e+05
# std     17164.865156  2.918424e+05
# min     45296.000000  1.307210e+05
# 25%     52788.750000  2.798242e+05
# 50%     62945.000000  3.669245e+05
# 75%     75677.250000  6.177612e+05
# max    120030.000000  1.436140e+06

# %%
corr = df.corr()
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col0 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col2 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col4 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col5 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col1 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col3 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col4 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col5 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row3_col0 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row3_col1 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row3_col2 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row3_col4 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row3_col5 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row4_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row4_col1 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row4_col2 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row4_col3 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row4_col5 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row5_col0 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row5_col1 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row5_col2 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row5_col3 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row5_col4 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Population</th>        <th class="col_heading level0 col1" >Density</th>        <th class="col_heading level0 col2" >Per_capita_income</th>        <th class="col_heading level0 col3" >Household income</th>        <th class="col_heading level0 col4" >Family income</th>        <th class="col_heading level0 col5" >HousePrice</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9level0_row0" class="row_heading level0 row0" >Population</th>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col1" class="data row0 col1" >0.214050</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col2" class="data row0 col2" >0.129885</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col3" class="data row0 col3" >0.213370</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col4" class="data row0 col4" >0.136799</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row0_col5" class="data row0 col5" >0.259032</td>
#             </tr>
#             <tr>
#                         <th id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9level0_row1" class="row_heading level0 row1" >Density</th>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col0" class="data row1 col0" >0.214050</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col2" class="data row1 col2" >0.473253</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col3" class="data row1 col3" >0.355580</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col4" class="data row1 col4" >0.338975</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row1_col5" class="data row1 col5" >0.576835</td>
#             </tr>
#             <tr>
#                         <th id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9level0_row2" class="row_heading level0 row2" >Per_capita_income</th>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col0" class="data row2 col0" >0.129885</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col1" class="data row2 col1" >0.473253</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col3" class="data row2 col3" >0.871630</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col4" class="data row2 col4" >0.935717</td>
#                         <td id="T_ac32d8b6_7aae_11ea_9776_d0c6374e52a9row2_col5" class="data row2 col5" >0.891513</td>
#             </tr>
#             <tr>

# %%
sn.set(font_scale=1.5,style="white")
sn.lmplot(x="Per_capita_income",y="HousePrice",data=df)
plt.show()

# %% [markdown]
# # II. Visualzing counties of CA

# %%
from geopy.geocoders import Nominatim
import folium

# %%
df.head()
# Out:
#       County  Population  Density  Per_capita_income  Household income  \
# 0    Alameda     1559308   2109.8            36439.0           73775.0
# 1     Alpine        1202      1.6            24375.0           61343.0
# 2     Amador       37159     62.5            27373.0           52964.0
# 3      Butte      221578    135.4            24430.0           43165.0
# 4  Calaveras       44921     44.0            29296.0           54936.0
#
#    Family income  HousePrice
# 0        90822.0      880231
# 1        71932.0      424684
# 2        68765.0      312764
# 3        56934.0      327236
# 4        67100.0      330958

# %%
Counties = pd.Series(df['County'])

# %%
# define the dataframe columns
column_names = ['County', 'Latitude', 'Longitude'] 

# instantiate the dataframe
df_geo = pd.DataFrame(columns=column_names)

# %%
geolocator = Nominatim(user_agent="ca_explorer")
for data in Counties:
    location = geolocator.geocode(data)
    latitude = location.latitude
    longitude = location.longitude
    df_geo = df_geo.append({ 'County': data,
                            'Latitude': latitude,
                            'Longitude': longitude}, ignore_index=True)

# %%
df_geo.head()
# Out:
#       County   Latitude   Longitude
# 0    Alameda  37.609029 -121.899142
# 1     Alpine  38.589393 -119.834501
# 2     Amador  38.449089 -120.591102
# 3      Butte  39.651927 -121.585844
# 4  Calaveras  38.255818 -120.498149

# %%
df_geo.shape
# Out:
# (58, 3)

# %%
df_final = df.merge(df_geo,on='County')

# %%
df_final.head()
# Out:
#       County  Population  Density  Per_capita_income  Household income  \
# 0    Alameda     1559308   2109.8            36439.0           73775.0
# 1     Alpine        1202      1.6            24375.0           61343.0
# 2     Amador       37159     62.5            27373.0           52964.0
# 3      Butte      221578    135.4            24430.0           43165.0
# 4  Calaveras       44921     44.0            29296.0           54936.0
#
#    Family income  HousePrice   Latitude   Longitude
# 0        90822.0      880231  37.609029 -121.899142
# 1        71932.0      424684  38.589393 -119.834501
# 2        68765.0      312764  38.449089 -120.591102
# 3        56934.0      327236  39.651927 -121.585844
# 4        67100.0      330958  38.255818 -120.498149

# %%
address = 'Los Angeles, CA'

geolocator = Nominatim(user_agent="ca_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of California are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of California are 34.0536909, -118.2427666.

# %%
# create map of New York using latitude and longitude values
map_ca = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, county in zip(df_final['Latitude'], df_final['Longitude'],df_final['County']):
    label = '{}'.format(county)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ca)  
    
map_ca
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # III. Get venues information from Foursquare

# %%
import json # library to handle JSON files
import requests # library to handle requests
CLIENT_ID = 'DRUUVH4FH2H3Z51LPRXCRZSSN5BTTE2N4XZBPTZ42FSTTG2Y' # your Foursquare ID
CLIENT_SECRET = 'AJMVY5WMO1LAJFTRBVLFDRJYK1HDTA1MAFHP2N335KVAIU0X' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DRUUVH4FH2H3Z51LPRXCRZSSN5BTTE2N4XZBPTZ42FSTTG2Y
# CLIENT_SECRET:AJMVY5WMO1LAJFTRBVLFDRJYK1HDTA1MAFHP2N335KVAIU0X

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['County', 
                  'County Latitude', 
                  'County Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
ca_venues = getNearbyVenues(names=df_final['County'],
                                   latitudes=df_final['Latitude'],
                                   longitudes=df_final['Longitude']
                                  )

# %%
print(ca_venues.shape)
ca_venues.head(10)
# Out:
# (800, 7)
#          County  County Latitude  County Longitude  \
# 0  Contra Costa        37.903481       -121.917535
# 1  Contra Costa        37.903481       -121.917535
# 2  Contra Costa        37.903481       -121.917535
# 3  Contra Costa        37.903481       -121.917535
# 4     El Dorado        33.207630        -92.666267
# 5     El Dorado        33.207630        -92.666267
# 6     El Dorado        33.207630        -92.666267
# 7     El Dorado        33.207630        -92.666267
# 8     El Dorado        33.207630        -92.666267
# 9     El Dorado        33.207630        -92.666267
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0  Donner Canyon Hiking Trail       37.911125      -121.923036
# 1                 Falls Trail       37.903110      -121.915600
# 2                Middle Trail       37.900475      -121.919464
# 3         Meridian Ridge Road       37.903630      -121.923070
# 4            Johnny B's Grill       33.210773       -92.665407
# 5                 PJ's Coffee       33.211910       -92.663944
# 6           Main Street Pizza       33.211984       -92.661066
# 7          El Dorado Creamery       33.211936       -92.663838
# 8                  Minute Man       33.212143       -92.666850
# 9                 Healthworks       33.213168       -92.660337
#
#        Venue Category
# 0               Trail
# 1               Trail
# 2               Trail
# 3               Trail
# 4               Diner
# 5         Coffee Shop
# 6         Pizza Place
# 7  Frozen Yogurt Shop
# 8        Burger Joint
# 9                 Gym

# %%
ca_venues.groupby('County').count()
# Out:
#                County Latitude  County Longitude  Venue  Venue Latitude  \
# County
# Contra Costa                 4                 4      4               4
# El Dorado                   19                19     19              19
# Fresno                       2                 2      2               2
# Kern                         1                 1      1               1
# Lake                         2                 2      2               2
# Los Angeles                100               100    100             100
# Marin                        1                 1      1               1
# Napa                       100               100    100             100
# Orange                      75                75     75              75
# Riverside                   82                82     82              82
# Sacramento                 100               100    100             100
# San Diego                  100               100    100             100
# San Francisco              100               100    100             100
# San Joaquin                  9                 9      9               9
# San Mateo                    2                 2      2               2
# Santa Barbara              100               100    100             100
# Sonoma                       1                 1      1               1
# Tehama                       2                 2      2               2
#
#                Venue Longitude  Venue Category
# County
# Contra Costa                 4               4
# El Dorado                   19              19
# Fresno                       2               2
# Kern                         1               1
# Lake                         2               2
# Los Angeles                100             100
# Marin                        1               1
# Napa                       100             100
# Orange                      75              75
# Riverside                   82              82
# Sacramento                 100             100
# San Diego                  100             100
# San Francisco              100             100
# San Joaquin                  9               9
# San Mateo                    2               2
# Santa Barbara              100             100
# Sonoma                       1               1
# Tehama                       2               2

# %%
ca_venues.groupby('Venue Category').count()
# Out:
#                      County  County Latitude  County Longitude  Venue  \
# Venue Category
# ATM                       1                1                 1      1
# Accessories Store         3                3                 3      3
# American Restaurant      25               25                25     25
# Antique Shop              1                1                 1      1
# Art Gallery               2                2                 2      2
# ...                     ...              ...               ...    ...
# Wine Bar                 15               15                15     15
# Wine Shop                 3                3                 3      3
# Winery                    1                1                 1      1
# Women's Store             1                1                 1      1
# Yoga Studio               2                2                 2      2
#
#                      Venue Latitude  Venue Longitude
# Venue Category
# ATM                               1                1
# Accessories Store                 3                3
# American Restaurant              25               25
# Antique Shop                      1                1
# Art Gallery                       2                2
# ...                             ...              ...
# Wine Bar                         15               15
# Wine Shop                         3                3
# Winery                            1                1
# Women's Store                     1                1
# Yoga Studio                       2                2
#
# [172 rows x 6 columns]

# %%
url = 'https://en.wikipedia.org/wiki/List_of_cities_and_towns_in_California'
dfs = pd.read_html(url)
dfs[1].head()
# Out:
#            Name  Type          County Population (2010)[1][8][9] Land area[1]  \
#            Name  Type          County Population (2010)[1][8][9]        sq mi
# 0      Adelanto  City  San Bernardino                      31765        56.01
# 1  Agoura Hills  City     Los Angeles                      20330         7.79
# 2       Alameda  City         Alameda                      73812        10.61
# 3        Albany  City         Alameda                      18539         1.79
# 4      Alhambra  City     Los Angeles                      83089         7.63
#
#              Incorporated[7]
#      km2     Incorporated[7]
# 0  145.1   December 22, 1970
# 1   20.2    December 8, 1982
# 2   27.5      April 19, 1854
# 3    4.6  September 22, 1908
# 4   19.8       July 11, 1903
